# %%
import pandas as pd
import numpy as np
Batting = pd.read_csv('../projectData/Batting.csv')
People = pd.read_csv('../projectData/People.csv')
HOF = pd.read_csv('../projectData/HallOfFame.csv')
HOF
HOF2024 = HOF[(HOF['yearid'] == 2025) & (HOF['inducted'] == 'Y')]
HOF2024
bobby = People[People['nameLast'] == 'Dalbec']
Batting
bobbyStats = Batting[Batting['playerID'] == 'dalbebo01']
bobbyStats
# Out:
#        playerID  yearid                  votedBy  ballots  needed  votes  \
# 0     aaronha01    1982                    BBWAA    415.0   312.0  406.0
# 1     abbotji01    2005                    BBWAA    516.0   387.0   13.0
# 2     abreubo01    2020                    BBWAA    397.0   298.0   22.0
# 3     abreubo01    2021                    BBWAA    401.0   301.0   35.0
# 4     abreubo01    2022                    BBWAA    394.0   296.0   34.0
# ...         ...     ...                      ...      ...     ...    ...
# 6413  zimmech01    1938                    BBWAA    262.0   197.0    1.0
# 6414  zimmedo01    2007  Veterans - Contributors      NaN     NaN    NaN
# 6415   ziskri01    1989                    BBWAA    447.0   336.0    0.0
# 6416   zitoba01    2021                    BBWAA    401.0   301.0    1.0
# 6417  zobribe01    2025                    BBWAA    394.0   296.0    0.0
#
#      inducted category                           needed_note
# ...

# %%
#merge data sets together (merge Batting stats and HOF) + (merge Pitching stats and HOF) (two different data sets since batting stats and pitching stats do not align with each other)

# %%
#random forests to determine most important features for both batting and pitching

# %%
#use the important features to run logistic regression

# %%
#test logistic regression model on past data to check how accurate it is

# %%
#make predictions into the future

# %%
#we could also use post season stats
