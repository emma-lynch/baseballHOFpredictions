# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score

# %%
pitching = pd.read_csv("../projectData/Pitching.csv")
people = pd.read_csv("../projectData/People.csv")
hof = pd.read_csv("../projectData/HallOfFame.csv")

# %%
people
# Out:
#           ID   playerID  birthYear  birthMonth  birthDay      birthCity  \
# 0          1  aardsda01     1981.0        12.0      27.0         Denver
# 1          2  aaronha01     1934.0         2.0       5.0         Mobile
# 2          3  aaronto01     1939.0         8.0       5.0         Mobile
# 3          4   aasedo01     1954.0         9.0       8.0         Orange
# 4          5   abadan01     1972.0         8.0      25.0     Palm Beach
# ...      ...        ...        ...         ...       ...            ...
# 21266  20672   zupofr01     1939.0         8.0      29.0  San Francisco
# 21267  20673  zuvelpa01     1958.0        10.0      31.0      San Mateo
# 21268  20674  zuverge01     1924.0         8.0      20.0        Holland
# 21269  20675  zwilldu01     1888.0        11.0       2.0      St. Louis
# 21270  20676   zychto01     1990.0         8.0       7.0          Monee
#
#       birthCountry birthState  deathYear  deathMonth  ...  nameLast  \
# 0              USA         CO        NaN         NaN  ...   Aardsma
# 1              USA         AL     2021.0         1.0  ...     Aaron
# 2              USA         AL     1984.0         8.0  ...     Aaron
# 3              USA         CA        NaN         NaN  ...      Aase
# 4              USA         FL        NaN         NaN  ...      Abad
# ...            ...        ...        ...         ...  ...       ...
# 21266          USA         CA     2005.0         3.0  ...      Zupo
# 21267          USA         CA        NaN         NaN  ...   Zuvella
# 21268          USA         MI     2014.0         9.0  ...  Zuverink
# 21269          USA         MO     1978.0         3.0  ...  Zwilling
# 21270          USA         IL        NaN         NaN  ...      Zych
#
#              nameGiven weight height bats throws       debut    bbrefID  \
# 0          David Allan  215.0   75.0    R      R  2004-04-06  aardsda01
# 1          Henry Louis  180.0   72.0    R      R  1954-04-13  aaronha01
# 2           Tommie Lee  190.0   75.0    R      R  1962-04-10  aaronto01
# 3       Donald William  190.0   75.0    R      R  1977-07-26   aasedo01
# 4        Fausto Andres  184.0   73.0    L      L  2001-09-10   abadan01
# ...                ...    ...    ...  ...    ...         ...        ...
# 21266     Frank Joseph  182.0   71.0    L      R  1957-07-01   zupofr01
# 21267             Paul  173.0   72.0    R      R  1982-09-04  zuvelpa01
# 21268           George  195.0   76.0    R      R  1951-04-21  zuverge01
# 21269  Edward Harrison  160.0   66.0    L      L  1910-08-14  zwilldu01
# 21270    Anthony Aaron  190.0   75.0    R      R  2015-09-04   zychto01
#
#         finalGame   retroID
# 0      2015-08-23  aardd001
# 1      1976-10-03  aaroh101
# 2      1971-09-26  aarot101
# 3      1990-10-03  aased001
# 4      2006-04-13  abada001
# ...           ...       ...
# 21266  1961-05-09  zupof101
# 21267  1991-05-02  zuvep001
# 21268  1959-06-15  zuveg101
# 21269  1916-07-12  zwild101
# 21270  2017-08-19  zycht001
#
# [21271 rows x 25 columns]

# %%
#career totals

# %%
pitching["IP"] = pitching["IPouts"] / 3
career = pitching.groupby("playerID").agg({
    "W": "sum",
    "L": "sum",
    "G": "sum",
    "GS": "sum",
    "CG": "sum",
    "SHO": "sum",
    "SV": "sum",
    "IPouts": "sum",
    "IP": "sum",
    "H": "sum",
    "ER": "sum",
    "HR": "sum",
    "BB": "sum",
    "SO": "sum",
    "IBB": "sum",
    "WP": "sum",
    "HBP": "sum",
    "BK": "sum",
    "BFP": "sum",
    "GF": "sum",
    "R": "sum",
    "SH": "sum",
    "SF": "sum",
    "GIDP": "sum"
}).reset_index()

# %%
# ERA
career["ERA_career"] = 9 * career["ER"] / career["IP"]

# WHIP
career["WHIP"] = (career["BB"] + career["H"]) / career["IP"]

# K/9, BB/9, HR/9
career["K9"]   = 9 * career["SO"] / career["IP"]
career["BB9"]  = 9 * career["BB"] / career["IP"]
career["HR9"]  = 9 * career["HR"] / career["IP"]

# K% and BB%
career["K_pct"]  = career["SO"] / career["BFP"]
career["BB_pct"] = career["BB"] / career["BFP"]

# %%
people["status"] = people["finalGame"].apply(
    lambda x: "retired" if pd.notna(x) else "active"
)

# %%
career = career.merge(
    people[["playerID", "nameGiven", "nameLast", "debut", "status"]],
    on="playerID",
    how="left"
)

career = career.dropna(subset=["ERA_career"])
career
# Out:
#         playerID   W   L    G  GS  CG  SHO  SV  IPouts           IP  ...  \
# 0      aardsda01  16  18  331   0   0    0  69    1011   337.000000  ...
# 1       aasedo01  66  60  448  91  22    5  82    3328  1109.333333  ...
# 2       abadfe01   9  29  406   6   0    0   2    1064   354.666667  ...
# 3      abbeybe01  22  40   79  65  52    0   1    1704   568.000000  ...
# 4      abbeych01   0   0    1   0   0    0   0       6     2.000000  ...
# ...          ...  ..  ..  ...  ..  ..  ...  ..     ...          ...  ...
# 10739  zulueyo01   0   0   12   0   0    0   0      49    16.333333  ...
# 10740  zumayjo01  13  12  171   0   0    0   5     629   209.666667  ...
# 10741  zuniggu01   0   0   17   0   0    0   2      59    19.666667  ...
# 10742  zuverge01  32  36  265  31   9    2  40    1927   642.333333  ...
# 10743   zychto01   7   3   70   1   0    0   1     218    72.666667  ...
#
#            WHIP         K9       BB9       HR9     K_pct    BB_pct  \
# 0      1.421365   9.080119  4.887240  1.094955  0.230508  0.124068
# 1      1.390024   5.200421  3.707632  0.722055  0.135518  0.096617
# 2      1.322368   7.409774  3.197368  1.141917  0.192994  0.083278
# 3      1.545775   2.551056  3.042254  0.285211  0.062695  0.074766
# 4      3.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# ...         ...        ...       ...       ...       ...       ...
# 10739  1.346939  11.020408  3.857143  1.102041  0.289855  0.101449
# 10740  1.349762   9.014308  4.893482  0.772655  0.230516  0.125137
# 10741  1.322034   7.322034  3.661017  2.288136  0.190476  0.095238
# 10742  1.343539   3.124546  2.844318  0.784639  0.081209  0.073926
# 10743  1.252294   9.908257  4.211009  0.371560  0.258900  0.110032
#
#                nameGiven  nameLast       debut   status
# 0            David Allan   Aardsma  2004-04-06  retired
# 1         Donald William      Aase  1977-07-26  retired
# 2       Fernando Antonio      Abad  2010-07-28  retired
# 3              Bert Wood     Abbey  1892-06-14  retired
# 4             Charles S.     Abbey  1893-08-16  retired
# ...                  ...       ...         ...      ...
# 10739        Yosver Jose   Zulueta  2024-06-25   active
# 10740        Joel Martin    Zumaya  2006-04-03  retired
# 10741  Guillermo Enrique    Zuñiga  2023-05-02   active
# 10742             George  Zuverink  1951-04-21  retired
# 10743      Anthony Aaron      Zych  2015-09-04  retired
#
# [10732 rows x 36 columns]

# %%
active = career[career['status'] == 'active']
active
# Out:
#         playerID   W   L    G  GS  CG  SHO  SV  IPouts          IP  ...  \
# 5      abbotan01  18  16   46  46   0    0   0     742  247.333333  ...
# 21     abreubr01  13   8  247   0   0    0   9     776  258.666667  ...
# 39      adamja01  19  11  276   0   0    0  24     809  269.666667  ...
# 42     adamsau02   7   7  188   2   0    0   0     467  155.666667  ...
# 59     adcocty01   0   0   15   0   0    0   0      60   20.000000  ...
# ...          ...  ..  ..  ...  ..  ..  ...  ..     ...         ...  ...
# 10711  zeferry01   0   0   12   0   0    0   0      51   17.000000  ...
# 10717  zerpaan01   7   5   79   6   0    0   0     337  112.333333  ...
# 10738  zuberty01   1   5   56   0   0    0   0     158   52.666667  ...
# 10739  zulueyo01   0   0   12   0   0    0   0      49   16.333333  ...
# 10741  zuniggu01   0   0   17   0   0    0   2      59   19.666667  ...
#
#            WHIP         K9       BB9       HR9     K_pct    BB_pct  \
# 5      1.305930   8.514825  3.493261  1.491914  0.223923  0.091866
# 21     1.179124  11.934278  4.070876  0.730670  0.319664  0.109040
# 39     0.997528  10.679852  3.304079  1.001236  0.295749  0.091497
# 42     1.336188  12.892934  5.665953  0.635974  0.316312  0.139007
# 59     1.000000   6.300000  0.900000  3.600000  0.177215  0.025316
# ...         ...        ...       ...       ...       ...       ...
# 10711  0.764706   9.529412  3.176471  0.000000  0.281250  0.093750
# 10717  1.317507   7.370920  2.483680  1.201780  0.189691  0.063918
# 10738  1.575949  10.082278  6.664557  1.879747  0.248945  0.164557
# 10739  1.346939  11.020408  3.857143  1.102041  0.289855  0.101449
# 10741  1.322034   7.322034  3.661017  2.288136  0.190476  0.095238
#
#                    nameGiven   nameLast       debut  status
# 5                Andrew Cole     Abbott  2023-06-05  active
# 21             Bryan Enrique      Abreu  2019-07-31  active
# 39             Jason Kendall       Adam  2018-05-05  active
# 42              Austin Lance      Adams  2017-07-15  active
# 59     Tyler Nathan McKenzie     Adcock  2023-06-12  active
# ...                      ...        ...         ...     ...
# 10711            Ryan Joseph  Zeferjahn  2024-08-25  active
# 10717            Angel David      Zerpa  2021-09-30  active
# 10738             John Tyler      Zuber  2020-07-24  active
# 10739            Yosver Jose    Zulueta  2024-06-25  active
# 10741      Guillermo Enrique     Zuñiga  2023-05-02  active
#
# [905 rows x 36 columns]

# %%
retired = career[career['status'] == 'retired'].copy()
retired
# Out:
#         playerID   W   L    G  GS  CG  SHO  SV  IPouts           IP  ...  \
# 0      aardsda01  16  18  331   0   0    0  69    1011   337.000000  ...
# 1       aasedo01  66  60  448  91  22    5  82    3328  1109.333333  ...
# 2       abadfe01   9  29  406   6   0    0   2    1064   354.666667  ...
# 3      abbeybe01  22  40   79  65  52    0   1    1704   568.000000  ...
# 4      abbeych01   0   0    1   0   0    0   0       6     2.000000  ...
# ...          ...  ..  ..  ...  ..  ..  ...  ..     ...          ...  ...
# 10736  zoldasa01  43  53  250  93  30    5   8    2788   929.333333  ...
# 10737  zuberbi01  43  42  224  65  23    3   6    2358   786.000000  ...
# 10740  zumayjo01  13  12  171   0   0    0   5     629   209.666667  ...
# 10742  zuverge01  32  36  265  31   9    2  40    1927   642.333333  ...
# 10743   zychto01   7   3   70   1   0    0   1     218    72.666667  ...
#
#            WHIP        K9       BB9       HR9     K_pct    BB_pct  \
# 0      1.421365  9.080119  4.887240  1.094955  0.230508  0.124068
# 1      1.390024  5.200421  3.707632  0.722055  0.135518  0.096617
# 2      1.322368  7.409774  3.197368  1.141917  0.192994  0.083278
# 3      1.545775  2.551056  3.042254  0.285211  0.062695  0.074766
# 4      3.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...         ...       ...       ...       ...       ...       ...
# 10736  1.352582  2.004663  2.914993  0.522956  0.052458  0.076280
# 10737  1.571247  4.385496  5.358779  0.400763  0.110184  0.134638
# 10740  1.349762  9.014308  4.893482  0.772655  0.230516  0.125137
# 10742  1.343539  3.124546  2.844318  0.784639  0.081209  0.073926
# 10743  1.252294  9.908257  4.211009  0.371560  0.258900  0.110032
#
#               nameGiven  nameLast       debut   status
# 0           David Allan   Aardsma  2004-04-06  retired
# 1        Donald William      Aase  1977-07-26  retired
# 2      Fernando Antonio      Abad  2010-07-28  retired
# 3             Bert Wood     Abbey  1892-06-14  retired
# 4            Charles S.     Abbey  1893-08-16  retired
# ...                 ...       ...         ...      ...
# 10736     Samuel Walter    Zoldak  1944-05-13  retired
# 10737     William Henry     Zuber  1936-09-16  retired
# 10740       Joel Martin    Zumaya  2006-04-03  retired
# 10742            George  Zuverink  1951-04-21  retired
# 10743     Anthony Aaron      Zych  2015-09-04  retired
#
# [9827 rows x 36 columns]

# %%
retired = retired.merge(
    hof[["playerID", "inducted"]],
    on="playerID",
    how="left"
)

# %%
retired
# Out:
#         playerID   W   L    G  GS  CG  SHO  SV  IPouts           IP  ...  \
# 0      aardsda01  16  18  331   0   0    0  69    1011   337.000000  ...
# 1       aasedo01  66  60  448  91  22    5  82    3328  1109.333333  ...
# 2       abadfe01   9  29  406   6   0    0   2    1064   354.666667  ...
# 3      abbeybe01  22  40   79  65  52    0   1    1704   568.000000  ...
# 4      abbeych01   0   0    1   0   0    0   0       6     2.000000  ...
# ...          ...  ..  ..  ...  ..  ..  ...  ..     ...          ...  ...
# 11684  zoldasa01  43  53  250  93  30    5   8    2788   929.333333  ...
# 11685  zuberbi01  43  42  224  65  23    3   6    2358   786.000000  ...
# 11686  zumayjo01  13  12  171   0   0    0   5     629   209.666667  ...
# 11687  zuverge01  32  36  265  31   9    2  40    1927   642.333333  ...
# 11688   zychto01   7   3   70   1   0    0   1     218    72.666667  ...
#
#              K9       BB9       HR9     K_pct    BB_pct         nameGiven  \
# 0      9.080119  4.887240  1.094955  0.230508  0.124068       David Allan
# 1      5.200421  3.707632  0.722055  0.135518  0.096617    Donald William
# 2      7.409774  3.197368  1.141917  0.192994  0.083278  Fernando Antonio
# 3      2.551056  3.042254  0.285211  0.062695  0.074766         Bert Wood
# 4      0.000000  0.000000  0.000000  0.000000  0.000000        Charles S.
# ...         ...       ...       ...       ...       ...               ...
# 11684  2.004663  2.914993  0.522956  0.052458  0.076280     Samuel Walter
# 11685  4.385496  5.358779  0.400763  0.110184  0.134638     William Henry
# 11686  9.014308  4.893482  0.772655  0.230516  0.125137       Joel Martin
# 11687  3.124546  2.844318  0.784639  0.081209  0.073926            George
# 11688  9.908257  4.211009  0.371560  0.258900  0.110032     Anthony Aaron
#
#        nameLast       debut   status  inducted
# 0       Aardsma  2004-04-06  retired       NaN
# 1          Aase  1977-07-26  retired       NaN
# 2          Abad  2010-07-28  retired       NaN
# 3         Abbey  1892-06-14  retired       NaN
# 4         Abbey  1893-08-16  retired       NaN
# ...         ...         ...      ...       ...
# 11684    Zoldak  1944-05-13  retired       NaN
# 11685     Zuber  1936-09-16  retired       NaN
# 11686    Zumaya  2006-04-03  retired       NaN
# 11687  Zuverink  1951-04-21  retired       NaN
# 11688      Zych  2015-09-04  retired       NaN
#
# [11689 rows x 37 columns]

# %%
retired["inducted"] = retired["inducted"].map({"Y": 1, "N": 0})
retired["inducted"] = retired["inducted"].fillna(0)  # Not voted = 0

# %%
features = [
    "IP","W","SO","H","ERA_career","G","HR9","BB","WHIP",
    "GS","L","BB9","K9","HR","SV"
]

# Replace missing values with 0
retired[features] = retired[features].fillna(0)

# %%
X = retired[features]
y = retired["inducted"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# %%
X_train = retired[features]
y_train = retired["inducted"]
# Replace inf/-inf with NaN
X_train = X_train.replace([np.inf, -np.inf], np.nan)
X_test = X_test.replace([np.inf,-np.inf],np.nan)
# Fill NaN with 0
X_train = X_train.fillna(0)
X_test = X_test.fillna(0)

# %%
rf = RandomForestClassifier(
    n_estimators=500,
    random_state=42,
    class_weight="balanced"
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=500,
#                        random_state=42)

# %%
# Predictions
y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)[:,1]

# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.93      0.97      2894
#          1.0       0.13      1.00      0.23        29
#
#     accuracy                           0.93      2923
#    macro avg       0.57      0.97      0.60      2923
# weighted avg       0.99      0.93      0.96      2923

# %%
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# ROC-AUC: 0.980238543478779

# %%
active
# Out:
#         playerID   W   L    G  GS  CG  SHO  SV  IPouts          IP  ...  \
# 5      abbotan01  18  16   46  46   0    0   0     742  247.333333  ...
# 21     abreubr01  13   8  247   0   0    0   9     776  258.666667  ...
# 39      adamja01  19  11  276   0   0    0  24     809  269.666667  ...
# 42     adamsau02   7   7  188   2   0    0   0     467  155.666667  ...
# 59     adcocty01   0   0   15   0   0    0   0      60   20.000000  ...
# ...          ...  ..  ..  ...  ..  ..  ...  ..     ...         ...  ...
# 10711  zeferry01   0   0   12   0   0    0   0      51   17.000000  ...
# 10717  zerpaan01   7   5   79   6   0    0   0     337  112.333333  ...
# 10738  zuberty01   1   5   56   0   0    0   0     158   52.666667  ...
# 10739  zulueyo01   0   0   12   0   0    0   0      49   16.333333  ...
# 10741  zuniggu01   0   0   17   0   0    0   2      59   19.666667  ...
#
#            WHIP         K9       BB9       HR9     K_pct    BB_pct  \
# 5      1.305930   8.514825  3.493261  1.491914  0.223923  0.091866
# 21     1.179124  11.934278  4.070876  0.730670  0.319664  0.109040
# 39     0.997528  10.679852  3.304079  1.001236  0.295749  0.091497
# 42     1.336188  12.892934  5.665953  0.635974  0.316312  0.139007
# 59     1.000000   6.300000  0.900000  3.600000  0.177215  0.025316
# ...         ...        ...       ...       ...       ...       ...
# 10711  0.764706   9.529412  3.176471  0.000000  0.281250  0.093750
# 10717  1.317507   7.370920  2.483680  1.201780  0.189691  0.063918
# 10738  1.575949  10.082278  6.664557  1.879747  0.248945  0.164557
# 10739  1.346939  11.020408  3.857143  1.102041  0.289855  0.101449
# 10741  1.322034   7.322034  3.661017  2.288136  0.190476  0.095238
#
#                    nameGiven   nameLast       debut  status
# 5                Andrew Cole     Abbott  2023-06-05  active
# 21             Bryan Enrique      Abreu  2019-07-31  active
# 39             Jason Kendall       Adam  2018-05-05  active
# 42              Austin Lance      Adams  2017-07-15  active
# 59     Tyler Nathan McKenzie     Adcock  2023-06-12  active
# ...                      ...        ...         ...     ...
# 10711            Ryan Joseph  Zeferjahn  2024-08-25  active
# 10717            Angel David      Zerpa  2021-09-30  active
# 10738             John Tyler      Zuber  2020-07-24  active
# 10739            Yosver Jose    Zulueta  2024-06-25  active
# 10741      Guillermo Enrique     Zuñiga  2023-05-02  active
#
# [905 rows x 36 columns]

# %%
active[features] = active[features].replace([np.inf, -np.inf], np.nan).fillna(0)
X_active = active[features]
# Out:
# C:\Users\kate\AppData\Local\Temp\ipykernel_40472\4083946320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   active[features] = active[features].replace([np.inf, -np.inf], np.nan).fillna(0)

# %%
active["hof_prob"] = rf.predict_proba(X_active)[:,1]  # probability of being inducted
# Out:
# C:\Users\kate\AppData\Local\Temp\ipykernel_40472\927259504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   active["hof_prob"] = rf.predict_proba(X_active)[:,1]  # probability of being inducted

# %%
top_active = active.sort_values("hof_prob", ascending=False)
top_active[["nameGiven", "nameLast", "hof_prob"]].head(20)
# Out:
#               nameGiven    nameLast  hof_prob
# 5044     Clayton Edward     Kershaw  0.434022
# 9935      Justin Brooks   Verlander  0.402660
# 4700    Kenley Geronimo      Jansen  0.349861
# 8588     Maxwell Martin    Scherzer  0.264756
# 5081      Craig Michael     Kimbrel  0.248755
# 1622   Albertin Aroldis     Chapman  0.147503
# 2274      Jacob Anthony      deGrom  0.138725
# 8445        Christopher        Sale  0.112372
# 4255      Jose Gregorio     Herrera  0.106855
# 10086      Andrew Wayne     Walters  0.094580
# 3038       Tyler Joseph  Fitzgerald  0.079897
# 8131         David Alan   Robertson  0.074067
# 5725     Rhett Hamilton      Lowder  0.062986
# 4598        Kyle Dillon        Hurt  0.052810
# 1802        Gerrit Alan        Cole  0.050524
# 3033      Richard Logan       Fitts  0.045514
# 4202        David James     Hensley  0.036731
# 6920           Nicholas    Nastrini  0.034000
# 9854              Ricky     Vanasco  0.025062
# 10389      Lucas Daniel    Williams  0.023746
